# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv(r'sales_data_sample.csv',encoding='latin1')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.drop(columns='ADDRESSLINE2')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df['STATE'].fillna('Unknown')
# Out:
# 0            NY
# 1       Unknown
# 2       Unknown
# 3            CA
# 4            CA
#          ...
# 2818    Unknown
# 2819    Unknown
# 2820    Unknown
# 2821    Unknown
# 2822         MA
# Name: STATE, Length: 2823, dtype: object

# %%
df['POSTALCODE'].fillna('Unknown')
# Out:
# 0         10022
# 1         51100
# 2         75508
# 3         90003
# 4       Unknown
#          ...
# 2818      28034
# 2819      90110
# 2820      28034
# 2821      31000
# 2822      51003
# Name: POSTALCODE, Length: 2823, dtype: object

# %%
df['TERRITORY'].fillna('Unknown')
# Out:
# 0       Unknown
# 1          EMEA
# 2          EMEA
# 3       Unknown
# 4       Unknown
#          ...
# 2818       EMEA
# 2819       EMEA
# 2820       EMEA
# 2821       EMEA
# 2822    Unknown
# Name: TERRITORY, Length: 2823, dtype: object

# %%
df.shape

# %%
df.info()

# check the sales over year
df.groupby(['YEAR_ID'])['SALES'].sum().sort_values(ascending=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
# 2004 has most sales

# %%
df['QUANTITYORDERED'].head(10)
# Out:
# 0    30
# 1    34
# 2    41
# 3    45
# 4    49
# 5    36
# 6    29
# 7    48
# 8    22
# 9    41
# Name: QUANTITYORDERED, dtype: int64

# %%
## line chart
plt.title('sales by year ')

df.groupby(['YEAR_ID'])['SALES'].sum().plot(kind='line')
plt.xlabel('year')
plt.ylabel('sales')
plt.xticks([2003,2004,2005])
# Out:
# ([<matplotlib.axis.XTick at 0x1b97e5a2010>,
# ...
#  [Text(2003, 0, '2003'), Text(2004, 0, '2004'), Text(2005, 0, '2005')])

# %%
# HIGHEST SALES RECORD IN 2004 AND LOWEST SALES RECORD IN 2005

# %%
df.groupby(['PRODUCTLINE'])['SALES'].sum().sort_values(ascending=False)
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Vintage Cars        1903150.84
# Motorcycles         1166388.34
# Trucks and Buses    1127789.84
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Name: SALES, dtype: float64

# %%
df.groupby(['PRODUCTLINE'])['SALES'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='PRODUCTLINE'>

# %%
sb.barplot(data = df ,x ='PRODUCTLINE',y='SALES' )
plt.title('Products with height sales')
plt.xlabel('products')
plt.ylabel('sales')
plt.xticks(rotation=45)

# %%
# classic cars sale record most around 4000+

# %%
# check sales by year
df.groupby(['YEAR_ID','PRODUCTLINE'])['SALES'].sum()#.idxmax()
# Out:
# YEAR_ID  PRODUCTLINE
# 2003     Classic Cars        1484785.29
#          Motorcycles          370895.58
#          Planes               272257.60
#          Ships                244821.09
#          Trains                72802.29
#          Trucks and Buses     420429.93
#          Vintage Cars         650987.76
# 2004     Classic Cars        1762257.09
#          Motorcycles          560545.23
#          Planes               502671.80
#          Ships                341437.97
#          Trains               116523.85
#          Trucks and Buses     529302.89
#          Vintage Cars         911423.77
# 2005     Classic Cars         672573.28
#          Motorcycles          234947.53
#          Planes               200074.17
#          Ships                128178.07
#          Trains                36917.33
#          Trucks and Buses     178057.02
#          Vintage Cars         340739.31
# Name: SALES, dtype: float64

# %%
df.pivot_table(index='YEAR_ID',columns='PRODUCTLINE',values='SALES',aggfunc='sum')
# Out:
# PRODUCTLINE  Classic Cars  Motorcycles     Planes      Ships     Trains  \
# YEAR_ID
# 2003           1484785.29    370895.58  272257.60  244821.09   72802.29
# 2004           1762257.09    560545.23  502671.80  341437.97  116523.85
# 2005            672573.28    234947.53  200074.17  128178.07   36917.33
#
# PRODUCTLINE  Trucks and Buses  Vintage Cars
# YEAR_ID
# 2003                420429.93     650987.76
# 2004                529302.89     911423.77
# 2005                178057.02     340739.31

# %%
df.pivot_table(index='YEAR_ID',columns='PRODUCTLINE',values='SALES',aggfunc='sum').plot(kind='bar',stacked=True)
plt.ylabel('products')
plt.title('top products')
# Out:
# Text(0.5, 1.0, 'top products')

# %%
# reginal analysis
df.groupby(['COUNTRY'])['SALES'].sum().sort_values(ascending=False)
# Out:
# COUNTRY
# USA            3627982.83
# Spain          1215686.92
# France         1110916.52
# Australia       630623.10
# UK              478880.46
# Italy           374674.31
# Finland         329581.91
# Norway          307463.70
# Singapore       288488.41
# Denmark         245637.15
# Canada          224078.56
# Germany         220472.09
# Sweden          210014.21
# Austria         202062.53
# Japan           188167.81
# Switzerland     117713.56
# Belgium         108412.62
# Philippines      94015.73
# Ireland          57756.43
# Name: SALES, dtype: float64

# %%
df.groupby(['COUNTRY'])['SALES'].sum().sort_values(ascending=False).plot(kind='bar',color=['r','orange','green','purple','violet','pink','orange'])
# .plot(kind='bar',colormap='tab10')
# .plot(kind='bar',color=['r','orange','green','purple','violet','pink','orange'])d
plt.xticks(rotation=45)
plt.ylabel('sales')
plt.title('top regional sales')
plt.figure(figsize=(8,6))

# %%
# USE HAS MOST SALES

# %%
df.groupby(['COUNTRY','PRODUCTLINE'])['SALES'].sum()
# Out:
# COUNTRY    PRODUCTLINE
# Australia  Classic Cars        193085.54
#            Motorcycles          89968.76
#            Planes               74853.87
#            Ships                 4159.76
#            Trains                1681.35
#                                  ...
# USA        Planes              328432.89
#            Ships               209688.14
#            Trains               69253.56
#            Trucks and Buses    397842.42
#            Vintage Cars        757755.90
# Name: SALES, Length: 116, dtype: float64

# %%
df.pivot_table(index= 'COUNTRY',columns='PRODUCTLINE',values='SALES',aggfunc='sum')
# Out:
# COUNTRY
# Australia       630623.10
# Austria         202062.53
# Belgium         108412.62
# Canada          224078.56
# Denmark         245637.15
# Finland         329581.91
# France         1110916.52
# Germany         220472.09
# Ireland          57756.43
# Italy           374674.31
# Japan           188167.81
# Norway          307463.70
# Philippines      94015.73
# Singapore       288488.41
# Spain          1215686.92
# Sweden          210014.21
# Switzerland     117713.56
# UK              478880.46
# USA            3627982.83
# dtype: float64

# %%
vl=df.pivot_table(index= 'COUNTRY',columns='PRODUCTLINE',values='SALES',aggfunc='sum').sum(axis=1).sort_values(ascending=False).head(10).index

# %%
sl=df.pivot_table(index= 'COUNTRY',columns='PRODUCTLINE',values='SALES',aggfunc='sum')

# %%
vl
# Out:
# Index(['USA', 'Spain', 'France', 'Australia', 'UK', 'Italy', 'Finland',
#        'Norway', 'Singapore', 'Denmark'],
#       dtype='object', name='COUNTRY')

# %%
sl.loc[vl].plot(kind='bar')
# Out:
# <Axes: xlabel='COUNTRY'>

# %%
# analysis by months
df.groupby(['MONTH_ID'])['SALES'].sum().sort_values(ascending=False)
# Out:
# MONTH_ID
# 11    2118885.67
# 10    1121215.22
# 5      923972.56
# 2      810441.90
# 1      785874.44
# 3      754501.39
# 4      669390.96
# 8      659310.57
# 12     634679.12
# 9      584724.27
# 7      514875.97
# 6      454756.78
# Name: SALES, dtype: float64

# %%
month_name = {
    1:'JAN',2:'FEB',3:'MAR',4:'APRIL',5:'MAY',6:'JUNE',
    7:'JUL',8:'AUG',9:'SEP',10:'OCT',11:'NOV',12:'DEC'
}

# %%
df['MONTH_NAME'] = df['MONTH_ID'].map(month_name)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.groupby(['MONTH_NAME'])['SALES'].sum().sort_index(ascending=False).plot(kind='bar',color=['orange','green','blue','pink','teal','r','yellow','purple','cyan'])
plt.title('TOP MONTH SALES')
plt.xlabel('MONTHS')
plt.ylabel('SALES')
# Out:
# Text(0, 0.5, 'SALES')

# %%
# region and month
df.groupby(['MONTH_NAME','COUNTRY'])['SALES'].sum()
# Out:
# MONTH_NAME  COUNTRY
# APRIL       Australia     50397.66
#             Austria       38629.14
#             Belgium        1711.26
#             Canada        31302.50
#             Denmark       57342.43
#                            ...
# SEP         Norway        16363.10
#             Singapore     87122.20
#             Spain         47727.82
#             Sweden        53941.69
#             USA          144178.91
# Name: SALES, Length: 120, dtype: float64

# %%
df.pivot_table(index= 'MONTH_NAME',columns=['PRODUCTLINE'],values='SALES',aggfunc='sum')
# Out:
# PRODUCTLINE  Classic Cars  Motorcycles     Planes      Ships    Trains  \
# MONTH_NAME
# APRIL           263252.00    119606.88  103359.77   33683.45   4756.47
# AUG             265302.43    106869.84   67352.01   52250.37  16168.12
# DEC             237291.07     46278.86   68497.74   24079.94  23181.14
# FEB             299647.80    122801.68  107905.65   68247.96  16507.95
# JAN             303070.56     81113.88   46715.81   61287.40  19026.58
# JUL             245292.95     60698.23   40915.32   22532.62  10802.20
# JUNE            137419.98     49879.42   68765.93   53274.53  10071.06
# MAR             277560.54     60469.98   79735.05   74341.94  22581.27
# MAY             365946.75    108335.97   74929.05   56156.30  20457.34
# NOV             825156.26    261057.36  175263.97  143075.65  44794.63
# OCT             465002.24    103649.61  106777.65   79791.74  25416.87
# SEP             234673.08     45626.63   34785.62   45715.23  12479.84
#
# ...

# %%
df.pivot_table(index= 'MONTH_NAME',columns=['PRODUCTLINE'],values='SALES',aggfunc='sum').plot(kind='bar')
# Out:
# <Axes: xlabel='MONTH_NAME'>

# %%
classic cars most sold in nove

# %%
# check sales in countres
df.groupby(['MONTH_NAME','COUNTRY'])['SALES'].sum().sort_values(ascending=False)
# Out:
# MONTH_NAME  COUNTRY
# NOV         USA          741331.68
# OCT         USA          416077.17
# AUG         USA          397979.10
# MAY         USA          300412.73
# DEC         USA          286443.82
#                            ...
# MAR         Singapore      4175.60
# AUG         Singapore      3127.88
#             France         2173.60
# APRIL       Belgium        1711.26
# AUG         Belgium        1637.20
# Name: SALES, Length: 120, dtype: float64

# %%
df.groupby(['MONTH_NAME','COUNTRY','PRODUCTLINE'])['SALES'].sum().sort_values(ascending=False)
# Out:
# MONTH_NAME  COUNTRY    PRODUCTLINE
# NOV         USA        Classic Cars    360339.94
# AUG         USA        Classic Cars    145362.99
# NOV         USA        Vintage Cars    143801.04
# OCT         USA        Vintage Cars    130167.14
# JUL         USA        Classic Cars    127374.81
#                                          ...
# AUG         Belgium    Vintage Cars      1637.20
# OCT         Austria    Vintage Cars      1345.75
# JUNE        Japan      Vintage Cars      1257.27
# DEC         Australia  Ships             1089.36
# APRIL       Japan      Vintage Cars       553.95
# Name: SALES, Length: 408, dtype: float64

# %% [markdown]
# USA HAS MOST  SALES OF CLASSIC CARS IN NOV

# %%
df.pivot_table(index='MONTH_ID',columns='COUNTRY',values='SALES',aggfunc='sum')
# Out:
# COUNTRY   Australia   Austria   Belgium    Canada    Denmark    Finland  \
# MONTH_ID
# 1          29852.17       NaN  16628.16       NaN        NaN  100428.89
# 2          71367.60       NaN  18800.09       NaN   58871.11   26422.82
# 3          35160.25   8775.16       NaN       NaN        NaN        NaN
# 4          50397.66  38629.14   1711.26  31302.50   57342.43   17813.40
# 5          68087.70  59475.10   8411.95  33692.97        NaN   31018.23
# 6               NaN       NaN       NaN  24564.53    4749.45        NaN
# 7          82029.22   6693.28  47760.48       NaN        NaN        NaN
# 8               NaN       NaN   1637.20  43332.35        NaN   31569.43
# 9          57832.05       NaN       NaN       NaN        NaN   80245.64
# 10              NaN  28550.59       NaN  36576.71  100595.55   42083.50
# 11        197991.30  59939.26  13463.48  15947.29   24078.61        NaN
# 12         37905.15       NaN       NaN  38662.21        NaN        NaN
#
# ...

# %%
df.groupby(['MONTH_NAME'])['PRICEEACH'].sum()
# Out:
# MONTH_NAME
# APRIL    14763.28
# AUG      15974.11
# DEC      14985.58
# FEB      18902.49
# JAN      19111.78
# JUL      12105.77
# JUNE     10873.51
# MAR      17432.61
# MAY      21137.41
# NOV      49990.43
# OCT      26613.22
# SEP      14277.88
# Name: PRICEEACH, dtype: float64

# %% [markdown]
# total revenu by months

# %%
df.groupby(['MONTH_NAME'])['PRICEEACH'].sum().plot(kind='bar',color='#FF0000')
plt.title('Total  REVENUE')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
# totla rev by contry
df.groupby(['COUNTRY'])['PRICEEACH'].sum()
# Out:
# COUNTRY
# Australia      15449.14
# Austria         4759.16
# Belgium         2887.31
# Canada          5957.05
# Denmark         5503.89
# Finland         7722.15
# France         25920.87
# Germany         5184.30
# Ireland         1377.98
# Italy           9329.40
# Japan           4290.26
# Norway          7318.18
# Philippines     2144.99
# Singapore       6581.90
# Spain          28042.54
# Sweden          4943.51
# Switzerland     2713.09
# UK             11882.70
# USA            84159.65
# Name: PRICEEACH, dtype: float64

# %%
df.groupby(['COUNTRY'])['PRICEEACH'].sum().sort_values(ascending=False).head(12).plot(
    kind='bar',color=colors
)
# Out:
# <Axes: xlabel='COUNTRY'>

# %%
colors = ["#264653", "#2A9D8F", "#E9C46A", "#F4A261", "#E76F51"]

# %%
# rev by years
df.groupby(['YEAR_ID'])['PRICEEACH'].sum()
# Out:
# YEAR_ID
# 2003     83793.14
# 2004    112488.10
# 2005     39886.83
# Name: PRICEEACH, dtype: float64

# %%
df.groupby(['YEAR_ID'])['PRICEEACH'].sum().plot(kind='bar',color=['cyan','pink','orange'])


plt.title(' ANNUAL REVENUE ')
# Out:
# Text(0.5, 1.0, ' ANNUAL REVENUE ')

# %%
# 2004 has most earned year

# %%
# check the most earing month then year by country
# month
df.pivot_table(index='MONTH_NAME',columns='COUNTRY',values='PRICEEACH',aggfunc='sum')
# Out:
# COUNTRY     Australia  Austria  Belgium   Canada  Denmark  Finland   France  \
# MONTH_NAME
# APRIL         1274.69  1114.01    63.38   976.00  1003.60   411.76  2517.26
# AUG               NaN      NaN    81.86  1189.00      NaN   737.37    57.20
# DEC           1114.63      NaN      NaN   954.47      NaN      NaN  1398.44
# FEB           1791.96      NaN   467.20      NaN  1279.26   535.59  1841.99
# JAN            776.87      NaN   300.00      NaN      NaN  2658.81  2612.49
# JUL           1879.74   160.47  1297.43      NaN      NaN      NaN  2775.58
# JUNE              NaN      NaN      NaN   731.73   147.30      NaN   145.70
# MAR            778.95   246.88      NaN      NaN      NaN      NaN  3321.31
# MAY           1593.78  1269.43   394.86   829.03      NaN   513.56  3897.84
# NOV           4676.68  1278.50   282.58   335.49   695.52      NaN  5241.45
# OCT               NaN   689.87      NaN   941.33  2378.21  1065.55  1966.81
# ...

# %%
sl = df.pivot_table(index='MONTH_NAME',columns='COUNTRY',values='PRICEEACH',aggfunc='sum').sum(axis=1).sort_values(ascending=False).head(6).index

# %%
val = df.pivot_table(index='MONTH_NAME',columns='COUNTRY',values='PRICEEACH',aggfunc='sum')

# %%
# val.loc[sl].plot(kind='bar')
# Out:
# <Axes: xlabel='MONTH_NAME'>

# %%
sl = df.pivot_table(index='MONTH_NAME',columns='COUNTRY',values='PRICEEACH',aggfunc='sum').sum(axis=1).sort_values(ascending=False)

# %%
sl
# Out:
# MONTH_NAME
# NOV      49990.43
# OCT      26613.22
# MAY      21137.41
# JAN      19111.78
# FEB      18902.49
# MAR      17432.61
# AUG      15974.11
# DEC      14985.58
# APRIL    14763.28
# SEP      14277.88
# JUL      12105.77
# JUNE     10873.51
# dtype: float64

# %%
# nov has most rev

# %%
# most price
df.pivot_table(index = 'YEAR_ID',columns='COUNTRY',values='PRICEEACH',aggfunc='sum')
# Out:
# COUNTRY  Australia  Austria  Belgium   Canada  Denmark  Finland    France  \
# YEAR_ID
# 2003       6453.10  2167.02   145.24  1289.96  2362.94  2676.36   7366.44
# 2004       5529.77  1075.83  2047.21  3838.06  2840.95  1851.39  13330.42
# 2005       3466.27  1516.31   694.86   829.03   300.00  3194.40   5224.01
#
# COUNTRY  Germany  Ireland    Italy    Japan   Norway  Philippines  Singapore  \
# YEAR_ID
# 2003     1750.11      NaN  3510.21      NaN  4690.85      1794.33    3524.07
# 2004     3434.19  1377.98  4660.56  3423.15  2627.33       350.66    2833.39
# 2005         NaN      NaN  1158.63   867.11      NaN          NaN     224.44
#
# COUNTRY     Spain   Sweden  Switzerland       UK       USA
# YEAR_ID
# 2003      9645.87  1505.39          NaN  4297.12  30614.13
# 2004     11234.59  2735.82      2713.09  6845.14  39738.57
# 2005      7162.08   702.30          NaN   740.44  13806.95

# %%
df.pivot_table(index = 'YEAR_ID',columns='COUNTRY',values='PRICEEACH',aggfunc='sum').sum(axis=1).sort_values(ascending=False)
# Out:
# YEAR_ID
# 2004    112488.10
# 2003     83793.14
# 2005     39886.83
# dtype: float64

# %%
# check reven by year and country
df.pivot_table(index = 'COUNTRY',columns='YEAR_ID',values='PRICEEACH',aggfunc='sum').sum(axis=1).sort_values(ascending=False)
# Out:
# COUNTRY
# USA            84159.65
# Spain          28042.54
# France         25920.87
# Australia      15449.14
# UK             11882.70
# Italy           9329.40
# Finland         7722.15
# Norway          7318.18
# Singapore       6581.90
# Canada          5957.05
# Denmark         5503.89
# Germany         5184.30
# Sweden          4943.51
# Austria         4759.16
# Japan           4290.26
# Belgium         2887.31
# Switzerland     2713.09
# Philippines     2144.99
# Ireland         1377.98
# dtype: float64

# %%
# PRODUCT AND MONTHS BY PRICE
df.groupby(['PRODUCTLINE'])['PRICEEACH'].sum()
# Out:
# PRODUCTLINE
# Classic Cars        84453.70
# Motorcycles         27472.19
# Planes              25012.72
# Ships               19622.18
# Trains               5825.41
# Trucks and Buses    26345.91
# Vintage Cars        47435.96
# Name: PRICEEACH, dtype: float64

# %%
df.groupby(['PRODUCTLINE'])['PRICEEACH'].sum().plot(kind='bar',color=colors)
plt.title('top products')
# Out:
# Text(0.5, 1.0, 'top products')

# %%
# month most product earned reve
# WHICH HAS MOST REVENUE EARNED BY PROD
df.pivot_table(index ='COUNTRY' , columns='PRODUCTLINE',values='PRICEEACH',aggfunc='sum')
# Out:
# PRODUCTLINE  Classic Cars  Motorcycles   Planes    Ships   Trains  \
# COUNTRY
# Australia         4521.61      2153.33  2136.75   141.34    50.95
# Austria           2258.84       471.02   437.28   326.04      NaN
# Belgium            400.00          NaN   100.00   937.15   244.05
# Canada            1334.62       100.00   820.53  1116.52      NaN
# Denmark           3077.59          NaN   200.00  1116.25   328.00
# Finland           3325.13      1095.58   892.74   808.39   113.56
# France            8339.71      5478.94  2630.92  1734.30   615.25
# Germany           3196.04       182.93   655.51   196.34   113.04
# Ireland            556.07       165.51   355.24      NaN   121.36
# Italy             2543.21       187.60  2562.27   515.39   228.44
# Japan              780.92       683.42  1332.70   445.60   143.29
# Norway            3083.16      1248.56   889.89      NaN   200.00
# Philippines       1171.90       503.74   397.68      NaN      NaN
# ...

# %%
df.pivot_table(index ='COUNTRY' , columns='PRODUCTLINE',values='PRICEEACH',aggfunc='sum').tail(12).plot(kind='bar')
# Out:
# <Axes: xlabel='COUNTRY'>

# %%
df.pivot_table(index ='COUNTRY' , columns='PRODUCTLINE',values='PRICEEACH',aggfunc='sum').sum(axis=1).sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='COUNTRY'>

# %%
# most product earn revenue in usa is classic cars

# %%
# now check the qunatity by
df.groupby(['PRODUCTLINE'])['QUANTITYORDERED'].sum()
# Out:
# PRODUCTLINE
# Classic Cars        33992
# Motorcycles         11663
# Planes              10727
# Ships                8127
# Trains               2712
# Trucks and Buses    10777
# Vintage Cars        21069
# Name: QUANTITYORDERED, dtype: int64

# %%
df.groupby(['PRODUCTLINE'])['QUANTITYORDERED'].sum().plot(kind='bar',color=colors)
plt.title('top sold item')
plt.ylabel('qunatity')
plt.xlabel('products')
# Out:
# <Axes: xlabel='PRODUCTLINE'>

# %%
# count by year 
df.groupby(['YEAR_ID','PRODUCTLINE'])['QUANTITYORDERED'].sum()
# Out:
# YEAR_ID  PRODUCTLINE
# 2003     Classic Cars        12473
#          Motorcycles          3739
#          Planes               2996
#          Ships                2844
#          Trains               1000
#          Trucks and Buses     4056
#          Vintage Cars         7504
# 2004     Classic Cars        15418
#          Motorcycles          5690
#          Planes               5524
#          Ships                3937
#          Trains               1303
#          Trucks and Buses     5002
#          Vintage Cars         9950
# 2005     Classic Cars         6101
#          Motorcycles          2234
#          Planes               2207
#          Ships                1346
#          Trains                409
#          Trucks and Buses     1719
#          Vintage Cars         3615
# Name: QUANTITYORDERED, dtype: int64

# %%
df.groupby(['YEAR_ID','PRODUCTLINE'])['QUANTITYORDERED'].sum().plot(kind='bar',color=colors)
plt.title('top qunatity sold item year')
# Out:
# Text(0.5, 1.0, 'top qunatity sold item year')

# %%
# check prodcu quantity by month
df.groupby(['MONTH_NAME','PRODUCTLINE'])['QUANTITYORDERED'].sum()
# Out:
# MONTH_NAME  PRODUCTLINE
# APRIL       Classic Cars        2310
#             Motorcycles         1152
#             Planes              1171
#             Ships                399
#             Trains                69
#                                 ...
# SEP         Planes               360
#             Ships                520
#             Trains               181
#             Trucks and Buses     825
#             Vintage Cars        1380
# Name: QUANTITYORDERED, Length: 84, dtype: int64

# %%
df.groupby(['MONTH_NAME','PRODUCTLINE'])['QUANTITYORDERED'].sum().sort_values(ascending=False).head(7).plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='MONTH_NAME,PRODUCTLINE'>

# %%
# countrt 
df.groupby(['COUNTRY','PRODUCTLINE'])['QUANTITYORDERED'].sum()
# Out:
# COUNTRY    PRODUCTLINE
# Australia  Classic Cars        1818
#            Motorcycles          876
#            Planes               813
#            Ships                 56
#            Trains                33
#                                ...
# USA        Planes              3476
#            Ships               2395
#            Trains               912
#            Trucks and Buses    3932
#            Vintage Cars        8239
# Name: QUANTITYORDERED, Length: 116, dtype: int64

# %%
df.groupby(['COUNTRY','PRODUCTLINE'])['QUANTITYORDERED'].sum().sort_values(ascending=False).head(10).plot(kind='bar',
                                                                                                         color=colors)
plt.title('most item sold country')
# Out:
# Text(0.5, 1.0, 'most item sold country')

# %%
df.pivot_table(index='COUNTRY',columns=['MONTH_ID','PRODUCTLINE'],values='QUANTITYORDERED',aggfunc='sum')
# Out:
# MONTH_ID              1                                                     \
# PRODUCTLINE Classic Cars Motorcycles Planes  Ships Trains Trucks and Buses
# COUNTRY
# Australia           62.0         NaN    NaN    NaN    NaN            174.0
# Austria              NaN         NaN    NaN    NaN    NaN              NaN
# Belgium            117.0         NaN    NaN    NaN    NaN              NaN
# Canada               NaN         NaN    NaN    NaN    NaN              NaN
# Denmark              NaN         NaN    NaN    NaN    NaN              NaN
# Finland            401.0       146.0  175.0  239.0    NaN              NaN
# France             335.0       335.0    NaN  271.0   78.0              NaN
# Germany              NaN         NaN    NaN    NaN    NaN              NaN
# Ireland              NaN         NaN    NaN    NaN    NaN              NaN
# Italy                NaN         NaN    NaN    NaN    NaN              NaN
# ...
